# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib as plt
import seaborn as sn
# %matplotlib inline

# %%
y = np.array( [3, 6, 2, 5, 6, 2, 8, 9, 12, 23 ] )
x = np.array( [1, 2, 4, 8, 7, 1, 8, 23, 16, 11] )

df = pd.DataFrame( { "x": x, "y": y } )


sn.lmplot( y = "y", x = "x", data = df )
